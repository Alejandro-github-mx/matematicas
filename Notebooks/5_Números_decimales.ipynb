# %% [markdown]
# # **Packages**

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import math
from fractions import Fraction

# %% [markdown]
# # **Ejercicio 53**

# %%
# EJERCICIO 53

# Convierte las siguientes fracciones decimales a fracciones comunes.

# 1) 0.20
x = .20
print("1) 0.20: ", Fraction(x).limit_denominator())

# 2) 0.33
x = .33
print("2) 0.33: ", Fraction(x).limit_denominator())

# 3) 0.25
print("3) 0.25: ", Fraction(0.25))

# 4) 0.44
print("4) 0.44: ", Fraction(.44).limit_denominator())

# 5) 0.66
print("5) 0.66: ", Fraction(.66).limit_denominator())

# 6) 1.5
print("6) 1.5: ", Fraction(1.5))

# 7) 2.75
print("7) 2.75: ", Fraction(2.75))

# 8) 3.08
print("8) 3.08: ", Fraction(3.08).limit_denominator())

# 9) 0.005
print("9) 0.005: ", Fraction(0.005).limit_denominator())

# 10) 1.346

f = Fraction(1.346).limit_denominator()
entero  = f.numerator // f.denominator
residuo = f.numerator % f.denominator
print("10) 1.346: ", Fraction(1.346).limit_denominator())
print(f"{entero} {residuo}/{f.denominator}")
# Out:
# 1) 0.20:  1/5
# 2) 0.33:  33/100
# 3) 0.25:  1/4
# 4) 0.44:  11/25
# 5) 0.66:  33/50
# 6) 1.5:  3/2
# 7) 2.75:  11/4
# 8) 3.08:  77/25
# 9) 0.005:  1/200
# 10) 1.346:  673/500
# 1 173/500
